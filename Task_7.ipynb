# %% [markdown]
# # GRIP : The Sparks Foundation

# %% [markdown]
# ## Data Science & Business Analytics Intern

# %% [markdown]
# # Task 7 : Stock Market Prediction using Numerical and Textual Analysis

# %% [markdown]
# ### Dataset 1 -  Historical stock prices
# Link of dataset - https://finance.yahoo.com/
# ### Dataset 2 -  India News Headlines
# Link of dataset - https://bit.ly/36fFPI6

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Reading data numerical
# Data can be found at https://finance.yahoo.com/ and https://bit.ly/36fFPI6

# %%
stock_df = pd.read_csv("^BSESN.csv")
stock_df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2020-02-24  41037.011719  41037.011719  40306.359375  40363.230469
# 1  2020-02-25  40497.718750  40536.000000  40220.589844  40281.199219
# 2  2020-02-26  40194.890625  40255.390625  39760.390625  39888.960938
# 3  2020-02-27  39947.800781  39947.800781  39423.269531  39745.660156
# 4  2020-02-28  39087.468750  39087.468750  38219.968750  38297.289063
#
#       Adj Close   Volume
# 0  40363.230469   8100.0
# 1  40281.199219   7300.0
# 2  39888.960938   9000.0
# 3  39745.660156   9600.0
# 4  38297.289063  12700.0

# %%
stock_df.shape
# Out:
# (249, 7)

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       249 non-null    object
#  1   Open       246 non-null    float64
#  2   High       246 non-null    float64
#  3   Low        246 non-null    float64
#  4   Close      246 non-null    float64
#  5   Adj Close  246 non-null    float64
#  6   Volume     246 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.7+ KB

# %%
# Unique value in each columns
for i in stock_df.columns:
    print(i, len(stock_df[i].unique()))
# Out:
# Date 249
# Open 247
# High 247
# Low 247
# Close 247
# Adj Close 247
# Volume 148

# %%
# list of Features in dataset
list_columns = stock_df.columns
list_columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# ## Find averge , min, max, etc... for Continuous Variable

# %%
stock_df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count    246.000000    246.000000    246.000000    246.000000    246.000000
# mean   39067.116410  39356.723260  38643.510552  39006.093536  39006.093536
# std     6248.332472   6161.583975   6321.913582   6264.224174   6264.224174
# min    26499.810547  27462.869141  25638.900391  25981.240234  25981.240234
# 25%    34244.863281  34558.888672  33951.600586  34217.800781  34217.800781
# 50%    38464.285157  38734.275390  38185.416015  38408.246094  38408.246094
# 75%    43951.251953  44201.906250  43566.326172  43868.712891  43868.712891
# max    52400.031250  52516.761719  51863.609375  52104.171875  52104.171875
#
#               Volume
# count     246.000000
# mean    20607.317073
# std     16129.115115
# min      7300.000000
# 25%     15000.000000
# 50%     18300.000000
# 75%     22200.000000
# max    188300.000000

# %%
# plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(stock_df.describe(), annot = True, fmt = '.2f', cmap = 'rainbow')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title("Visualize average, numberOf, min, max, std, Queartile", fontsize = 16)
# Out:
# Text(0.5, 1, 'Visualize average, numberOf, min, max, std, Queartile')

# %% [markdown]
# ## Cheack Missing value

# %%
# cheack missing value
stock_df.isna().sum()
# Out:
# Date         0
# Open         3
# High         3
# Low          3
# Close        3
# Adj Close    3
# Volume       3
# dtype: int64

# %% [markdown]
# missing value avalible

# %%
# Treat missing value
stock_df.dropna(inplace=True)

# %%
# cheack missing value
stock_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Date transform
stock_df['Date'] = pd.to_datetime(stock_df['Date'] ,format='%Y-%m-%d')
stock_df.index = stock_df['Date']

# %%
# Open Price History plot
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['Open'])
plt.title("Open Price History", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %%
# Close Price History plot
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['Close'])
plt.title("Close Price History", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %%
# Stock Price Groth History plot
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['High'])
plt.title("Stock Price Groth History", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %%
# Stock Price lower History plot
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['Low'])
plt.title("Stock Price lower History", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %%
# Stock Price Adjustce and Close Price plot
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['Adj Close'])
plt.title("Stock Price Adjustce and Close Price", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %%
# Stock Price Volume plot
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['Volume'])
plt.title("Stock Price Volume", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %% [markdown]
# ## Stock market volume price Prediction

# %% [markdown]
# ## Misiing value care

# %%
# cheack missing value
stock_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
stock_df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object

# %% [markdown]
# ## Split dependent and independent data

# %%
X = stock_df.iloc[:, 1:7].values
y = stock_df.iloc[:, -1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %% [markdown]
# ## Standerd Scale transform

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# >## The Random Forest Regression

# %% [markdown]
# ## Training the Random Forest Regression model on the Training set

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

print("The Random Forest Regression model trained")
# Out:
# The Random Forest Regression model trained

# %% [markdown]
# ## Predicting test sat using Random Forest Regression trained model

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([20590., 14240., 27020., 15140., 20940., 14380., 15500., 14670.,
#        15160., 26900., 28340., 20920., 27900., 19200., 18380., 28340.,
#        20720., 21030., 20020., 22890., 19130., 15960., 17620., 16540.,
#        18300., 15600., 14660., 22050., 13670., 11450., 16500., 22400.,
#        12500., 13670., 34490., 15600., 25160., 18380., 15140., 14550.,
#        12160., 11450., 18750., 18920., 15160., 18460., 17220., 19530.,
#        39050., 34230., 19820., 21200., 15370., 15390., 24260., 28920.,
#        18400., 10660., 21020., 20020., 15420., 30290., 16880., 21130.,
#        21020., 17170., 24610., 32620., 10380., 10610., 31130., 20940.,
#        15960., 24860., 12650., 16540., 27070., 19450., 15140., 17820.,
#        18100., 18300.])

# %% [markdown]
# ## Visualize the Train Result

# %%
# create dataframe
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Pred_x_train = regressor.predict(X_train)

df['predict_train'] = Pred_x_train
df['predict_train']
# Out:
# 0      15500.0
# 1      12700.0
# 2      12860.0
# 3      33270.0
# 4       9470.0
#         ...
# 159    24660.0
# 160    15960.0
# 161    18610.0
# 162    19920.0
# 163    15420.0
# Name: predict_train, Length: 164, dtype: float64

# %%
plt.figure(figsize=(14, 8))
plt.plot(df['predict_train'])
plt.title("Stock Price Volume Train Result", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %% [markdown]
# ## Visualize the Test Result

# %%
df1 = pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1['predict'] = y_pred
df1['predict']
# Out:
# 0     20590.0
# 1     14240.0
# 2     27020.0
# 3     15140.0
# 4     20940.0
#        ...
# 77    19450.0
# 78    15140.0
# 79    17820.0
# 80    18100.0
# 81    18300.0
# Name: predict, Length: 82, dtype: float64

# %%
plt.figure(figsize=(14, 8))
plt.plot(df1['predict'])
plt.title("Stock Price Volume Test Result", fontsize = 16)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %% [markdown]
# ## Accuracy of model

# %%
print("Accuracy score : ", np.mean(y_pred==y_test))
# Out:
# Accuracy score :  0.07317073170731707

# %% [markdown]
# **Using model we can predict  **

# %% [markdown]
# ># Textual Analysis

# %% [markdown]
# ## Importing the dataset

# %%
news_df = pd.read_csv('india-news-headlines.csv')
news_df.head()
# Out:
#    publish_date headline_category  \
# 0      20010101        sports.wwe
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  win over cena satisfying but defeating underta...
# 1  Status quo will not be disturbed at Ayodhya; s...
# 2                Fissures in Hurriyat over Pak visit
# 3              America's unwanted heading for India?
# 4                 For bigwigs; it is destination Goa

# %%
news_df.shape
# Out:
# (3297172, 3)

# %%
news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3297172 entries, 0 to 3297171
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   publish_date       int64
#  1   headline_category  object
#  2   headline_text      object
# dtypes: int64(1), object(2)
# memory usage: 75.5+ MB

# %%
news_df.dtypes
# Out:
# publish_date          int64
# headline_category    object
# headline_text        object
# dtype: object

# %%
news_df['headline_text']
# Out:
# 0          win over cena satisfying but defeating underta...
# 1          Status quo will not be disturbed at Ayodhya; s...
# 2                        Fissures in Hurriyat over Pak visit
# 3                      America's unwanted heading for India?
# 4                         For bigwigs; it is destination Goa
#                                  ...
# 3297167        why tiktok removed 1 65 crore videos in india
# 3297168    apurva asrani calls alia bhatts mother soni ra...
# 3297169    kangana ranaut gets a doll version of herself ...
# 3297170    meezaan jaffrey reminisces his childhood days ...
# 3297171    prabhas20 titled as radhe shyam prabhas and po...
# Name: headline_text, Length: 3297172, dtype: object

# %% [markdown]
# ## Missing value

# %%
news_df.drop('headline_category', axis=1, inplace=True)
news_df['publish_date'] = pd.to_datetime(news_df['publish_date'], format='%Y%m%d')
news_df.head()
# Out:
#   publish_date                                      headline_text
# 0   2001-01-01  win over cena satisfying but defeating underta...
# 1   2001-01-02  Status quo will not be disturbed at Ayodhya; s...
# 2   2001-01-02                Fissures in Hurriyat over Pak visit
# 3   2001-01-02              America's unwanted heading for India?
# 4   2001-01-02                 For bigwigs; it is destination Goa

# %%
news_df.rename(columns={'publish_date': 'Date'}, inplace = True)

# %% [markdown]
# ## Duplicates remove data

# %%
news_df = news_df.drop_duplicates()
news_df.reset_index(inplace=True, drop=True)
news_df.head()
# Out:
#         Date                                      headline_text
# 0 2001-01-01  win over cena satisfying but defeating underta...
# 1 2001-01-02  Status quo will not be disturbed at Ayodhya; s...
# 2 2001-01-02                Fissures in Hurriyat over Pak visit
# 3 2001-01-02              America's unwanted heading for India?
# 4 2001-01-02                 For bigwigs; it is destination Goa

# %%
news_df = news_df[:6000]

# %% [markdown]
# We are using 6000 rows of data because of my device computation speed. So 6000 rows are quickly computation.

# %%
from textblob import TextBlob

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
news_df['Subjectivity'] = news_df['headline_text'].apply(getSubjectivity)
news_df['Polarity'] = news_df['headline_text'].apply(getPolarity)
news_df.head()
# Out:
#         Date                                      headline_text  Subjectivity  \
# 0 2001-01-01  win over cena satisfying but defeating underta...      0.633333
# 1 2001-01-02  Status quo will not be disturbed at Ayodhya; s...      0.000000
# 2 2001-01-02                Fissures in Hurriyat over Pak visit      0.000000
# 3 2001-01-02              America's unwanted heading for India?      0.000000
# 4 2001-01-02                 For bigwigs; it is destination Goa      0.000000
#
#    Polarity
# 0  0.433333
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4  0.000000

# %%
plt.figure(figsize = (12, 8))
news_df['Subjectivity'].hist()
plt.show()

# %%
plt.figure(figsize = (12, 8))
news_df['Polarity'].hist()
plt.show()

# %% [markdown]
# ## SentimentIntensity Analyzer

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 

senti_ana = SentimentIntensityAnalyzer()

# %%
news_df['compound'] = [senti_ana.polarity_scores(i)['compound'] for i in news_df['headline_text']]
news_df['Negative'] = [senti_ana.polarity_scores(i)['neg'] for i in news_df['headline_text']]
news_df['Neutral'] = [senti_ana.polarity_scores(i)['neu'] for i in news_df['headline_text']]
news_df['Positive'] = [senti_ana.polarity_scores(i)['pos'] for i in news_df['headline_text']]

news_df.head()
# Out:
#         Date                                      headline_text  Subjectivity  \
# 0 2001-01-01  win over cena satisfying but defeating underta...      0.633333
# 1 2001-01-02  Status quo will not be disturbed at Ayodhya; s...      0.000000
# 2 2001-01-02                Fissures in Hurriyat over Pak visit      0.000000
# 3 2001-01-02              America's unwanted heading for India?      0.000000
# 4 2001-01-02                 For bigwigs; it is destination Goa      0.000000
#
#    Polarity  compound  Negative  Neutral  Positive
# 0  0.433333   -0.0000     0.230    0.473     0.297
# 1  0.000000    0.2924     0.000    0.805     0.195
# 2  0.000000    0.0000     0.000    1.000     0.000
# 3  0.000000   -0.2263     0.322    0.678     0.000
# 4  0.000000    0.0000     0.000    1.000     0.000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We can using regressor model we can predict stock Volume price. The Accuracy of our prediction uing this model is **48 %** Accurate.
#
# As per my analyes News headline data contain first month of 2001 Date but the stock data Date have secound month of 2020 so news headline not much useful for stock prediction.
